# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
import pandas as pd

# %%
lumbar_df = pd.read_csv('/content/drive/MyDrive/CL/Day_2/lumbar_data.csv')

# %%
lumbar_df.sample(5)
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 185         91.468741    24.508177              84.620272     66.960564
# 273         35.877571     1.112374              43.457257     34.765197
# 123         65.665347    10.540675              56.489135     55.124672
# 173         50.825029     9.064729              56.300000     41.760300
# 109         68.613001    15.082235              63.014696     53.530766
#
#      pelvic_radius  degree_spondylolisthesis              class
# 185     117.307897                 52.623047  Spondylolisthesis
# 273     126.923906                 -1.632238             Normal
# 123     109.162777                 53.932020  Spondylolisthesis
# 173      78.999454                 23.041524  Spondylolisthesis
# 109     123.431174                 39.497987  Spondylolisthesis

# %%
lumbar_df.isnull().sum()
# Out:
# pelvic_incidence            0
# pelvic_tilt                 0
# lumbar_lordosis_angle       0
# sacral_slope                0
# pelvic_radius               0
# degree_spondylolisthesis    0
# class                       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lumbar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 17.1+ KB

# %%
lumbar_df['class'] = lumbar_df['class'].astype('category')

# %%
lumbar_df['class'] = lumbar_df['class'].replace('Normal',0).replace('Abnormal',1).replace('Spondylolisthesis',1).replace('Hernia',1)

# %%
lumbar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    category
# dtypes: category(1), float64(6)
# memory usage: 15.1 KB

# %%
lumbar_df
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis class
# 0        98.672917                 -0.254400     1
# ...

# %%
from sklearn.model_selection import train_test_split
lumbar_df.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis
# count     310.000000                310.000000
# mean      117.920655                 26.296694
# std        13.317377                 37.559027
# min        70.082575                -11.058179
# 25%       110.709196                  1.603727
# ...

# %%
lumbar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    category
# dtypes: category(1), float64(6)
# memory usage: 15.1 KB

# %%
X = lumbar_df.drop(['class'],axis=1)
y = lumbar_df['class']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
from sklearn.model_selection import GridSearchCV
params = [{
    'n_neighbors' :[ i for i in range(3,30,2)],
    'weights' : ['uniform','distance'],
    'leaf_size' : [10,20,30,40,50,60]}]

gscv = GridSearchCV(KNeighborsClassifier(),param_grid=params,cv=4,scoring='accuracy')
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'leaf_size': 10, 'n_neighbors': 17, 'weights': 'uniform'}

# %%
model = gscv.best_estimator_
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,model.predict(x_test))

# %%
accuracy
# Out:
# 0.8333333333333334
